# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("superstore_sales_dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel("superstore_sales_dataset.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
df = pd.read_excel("C:\\Users\\praha\\Documents\\superstore_sales_dataset.xlsx")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class    SM-20320
# 1    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class    TC-20980
# 2    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class    RB-19360
# 3    2624  CA-2017-127180 2017-10-22 2017-10-24     First Class    TA-21385
# 4    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class    HL-15040
#
#   Customer Name      Segment        Country           City  ... Postal Code  \
# 0   Sean Miller  Home Office  United States   Jacksonville  ...       32216
# 1  Tamara Chand    Corporate  United States      Lafayette  ...       47905
# 2  Raymond Buch     Consumer  United States        Seattle  ...       98115
# 3  Tom Ashbrook  Home Office  United States  New York City  ...       10024
# 4  Hunter Lopez     Consumer  United States         Newark  ...       19711
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355392
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df = df.dropna()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class    SM-20320
# 1    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class    TC-20980
# 2    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class    RB-19360
# 3    2624  CA-2017-127180 2017-10-22 2017-10-24     First Class    TA-21385
# 4    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class    HL-15040
#
#   Customer Name      Segment        Country           City  ...  \
# 0   Sean Miller  Home Office  United States   Jacksonville  ...
# 1  Tamara Chand    Corporate  United States      Lafayette  ...
# 2  Raymond Buch     Consumer  United States        Seattle  ...
# 3  Tom Ashbrook  Home Office  United States  New York City  ...
# 4  Hunter Lopez     Consumer  United States         Newark  ...
#
#         Product ID    Category Sub-Category  \
# 0  TEC-MA-10002412  Technology     Machines
# ...

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby('Region')['Profit'].sum()
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %%
df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head()
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64

# %%
df[df['Profit'] < 0]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
# 11       166  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# 12       684  US-2017-168116 2017-11-04 2017-11-04        Same Day
# 23      1804  CA-2017-158379 2017-09-22 2017-09-26    Second Class
# 27      7773  CA-2016-108196 2016-11-25 2016-12-02  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    2107  US-2014-152723 2014-09-26 2014-09-26        Same Day
# 9990    4712  CA-2014-112403 2014-03-31 2014-03-31        Same Day
# 9991    8659  CA-2016-168361 2016-06-21 2016-06-25  Standard Class
# 9992    9293  CA-2017-124114 2017-03-02 2017-03-02        Same Day
# 9993    4102  US-2017-102288 2017-06-19 2017-06-23  Standard Class
#
#      Customer ID     Customer Name      Segment        Country          City  \
# 0       SM-20320       Sean Miller  Home Office  United States  Jacksonville
# ...

# %%
total_sales = df['Sales'].sum()

# %%
import matplotlib.pyplot as plt

df.groupby('Region')['Sales'].sum().plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %%
df.groupby('Category')['Sales'].sum().plot(kind='bar')
plt.title("Sales by Category")
plt.show()

# %%
df.groupby('Month')['Sales'].sum().plot()
plt.title("Monthly Sales Trend")
plt.show()

# %%
import matplotlib.pyplot as plt

sales_region = df.groupby('Region')['Sales'].sum()

plt.figure(figsize=(8,5))
sales_region.plot(kind='bar')

plt.title("Sales by Region", fontsize=14)
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=0)

plt.show()

# %%
sales_category = df.groupby('Category')['Sales'].sum()

plt.figure(figsize=(8,5))
sales_category.plot(kind='bar')

plt.title("Sales by Category", fontsize=14)
plt.show()

# %%
df['Month'] = df['Order Date'].dt.month

monthly_sales = df.groupby('Month')['Sales'].sum()

plt.figure(figsize=(10,5))
monthly_sales.plot(kind='line', marker='o')

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
print("Insights:")
print("1. West region has highest sales")
print("2. Technology category generates most revenue")
print("3. Sales peak around end of year")
print("4. Some transactions have negative profit")
# Out:
# Insights:
# 1. West region has highest sales
# 2. Technology category generates most revenue
# 3. Sales peak around end of year
# 4. Some transactions have negative profit
